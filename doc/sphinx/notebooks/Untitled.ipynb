# %%
import dcgpy
from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
X, Y = dcgpy.generate_chwirut2()

# %%
plt.plot(X[0], Y[0], '.')
plt.title('54 measurments')
plt.xlabel('metal distance')
plt.ylabel('ultrasonic response')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0, 0.5, 'ultrasonic response')
